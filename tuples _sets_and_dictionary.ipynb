# %% [markdown]
# # Tuples are read only data type, other things are same as list

# %%
touples=(1,2,3,4)
len(touples)
# Out:
# 4

# %%
sorted(touples,reverse=True)
# Out:
# [4, 3, 2, 1]

# %% [markdown]
# # Sets
# # rules :
# # 1 sets donot allow duplicates
# # 2 sets donot have indexing / slice
# # 3 set donot allow mutable data type
# # 4 set it self a mutable data type
# # so 2d and 3d sets are not possible

# %%
s1={1,2 ,3,4,5}  
s1
# Out:
# {1, 2, 3, 4, 5}

# %%
s2={[1,2,3],"Ubaid"}
s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 s2={[1,2,3],"Ubaid"}
#       2 s2
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # see the error for list unhashable lets use with tuple

# %%
s2={(1,2,3),"Ubaid","Hello"}
s2
# Out:
# {(1, 2, 3), 'Hello', 'Ubaid'}

# %% [markdown]
# # In set indexing not matter we are using hashing technique to get position

# %% [markdown]
# # lets get example of indexing or slicing

# %%
s1[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 s1[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s1[:2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 s1[:2]
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# # indesing / slicing not working

# %% [markdown]
# # but we can add items

# %%
s1.add(50)
s1
# Out:
# {1, 2, 3, 4, 5, 50}

# %%
del s1

# %%
s1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s1
#
# NameError: name 's1' is not defined

# %%
# we can use loop
for i in s2:
    print(i)
# Out:
# Ubaid
# Hello
# (1, 2, 3)

# %%
# sorted
s1={4,6,4,9}
sorted(s1)
# Out:
# [4, 6, 9]

# %%
# specific sets function
s2={3,5,9}

s1.union(s2)
# Out:
# {3, 4, 5, 6, 9}

# %%
s1.intersection(s2)
# Out:
# {9}

# %%
s1.difference(s2)
# Out:
# {4, 6}

# %% [markdown]
# # Dictionary
# # key , value  pair
# # Roles :
# # 1 it has no indexing
# # 2 it is mutable
# # 3  Keys imutable , value mutable
# # 4 key will be unique

# %%
d={"name": 'ubaid' , "age":10 }
d
# Out:
# {'name': 'ubaid', 'age': 10}

# %%
d["name"]
# Out:
# 'ubaid'

# %% [markdown]
# # 2D dictionary

# %%
d2={"name": 'ubaid' , "age":10 ,"phone":{"p1":"073423424", "p2":"07234234"}}
d2["phone"]["p2"]
# Out:
# '07234234'

# %%
d2["university"]="abc"
d2
# Out:
# {'name': 'ubaid',
#  'age': 10,
#  'phone': {'p1': '073423424', 'p2': '07234234'},
#  'university': 'abc'}

# %%
del d2["age"]
d2
# Out:
# {'name': 'ubaid',
#  'phone': {'p1': '073423424', 'p2': '07234234'},
#  'university': 'abc'}

# %%
for i in d2:
    print(i,d2[i])
# Out:
# name ubaid
# phone {'p1': '073423424', 'p2': '07234234'}
# university abc

# %%
d2.keys()
for i in d2.keys():
    print(i)
# Out:
# name
# phone
# university
