# %% [markdown]
# # 2d

# %%
list=[1,2,3,[4,5]]
print(list[-1][1])
print(list[3][1])
# Out:
# 5
# 5

# %% [markdown]
# # 3d

# %%
list2=[[[1,2,3],[4,5,6]],[2,4]]
list2[1][0]
# Out:
# 2

# %% [markdown]
# # apply title on text using custom logic

# %%
sample="how are you"
list=sample.split(" ")
list2=[]
for i in (list):
   
    list2.append(i.capitalize())


" ".join(list2)
# Out:
# 'How Are You'

# %% [markdown]
# # Find username in email

# %%
email="abc@gmail.com"
list=email.split("@")
list[0]
# Out:
# 'abc'

# %%
for i in range(0,email.find("@")):
    print(email[i],end="")
# Out:
# abc

# %%
email[:email.find("@")]
# Out:
# 'abc'

# %% [markdown]
# # Avoid Duplicates

# %%
list=[1,1,2,3,4,2,1,4,6]

list2=[]

for i in list:
    if(i not in list2):
        list2.append(i)

list2
# Out:
# [1, 2, 3, 4, 6]
